# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
from penkit import textures

# %%
plt.axes().set_aspect('equal', 'datalim')
plt.plot(*textures.make_grid_texture());

# %%
plt.axes().set_aspect('equal', 'datalim')
plt.plot(*textures.make_grid_texture(5, 5));

# %%
plt.axes().set_aspect('equal', 'datalim')
plt.plot(*textures.make_lines_texture());

# %%
plt.axes().set_aspect('equal', 'datalim')
plt.plot(*textures.make_hex_texture(6));

# %%
plt.axes().set_aspect('equal', 'datalim')
plt.plot(*textures.make_spiral_texture(1000, 6));
