# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
from penkit import surfaces

# %%
plt.imshow(surfaces.make_bubble_surface(), cmap='gray');

# %%
plt.imshow(surfaces.make_noise_surface(), cmap='gray');

# %%
plt.imshow(surfaces.make_sine_surface(), cmap='gray');
